# %%
import pandas as pd

# %%
df = pd.read_csv('movies.csv',index_col=0)
df.head()
# Out:
#           budget                                    genres  \
# index
# 0      237000000  Action Adventure Fantasy Science Fiction
# 1      300000000                  Adventure Fantasy Action
# 2      245000000                    Action Adventure Crime
# 3      250000000               Action Crime Drama Thriller
# 4      260000000          Action Adventure Science Fiction
#
#                                            homepage      id  \
# index
# 0                       http://www.avatarmovie.com/   19995
# 1      http://disney.go.com/disneypictures/pirates/     285
# 2       http://www.sonypictures.com/movies/spectre/  206647
# 3                http://www.thedarkknightrises.com/   49026
# 4              http://movies.disney.com/john-carter   49529
#
#                                                 keywords original_language  \
# index
# 0      culture clash future space war space colony so...                en
# ...

# %%
len(df)
# Out:
# 4803

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4803 entries, 0 to 4802
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4775 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4391 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
df[['genres', 'keywords', 'director', 'cast']].isna().sum()
# Out:
# genres       28
# keywords    412
# director     30
# cast         43
# dtype: int64

# %%
df[df[['genres', 'keywords', 'director', 'cast']].isna().any(axis=1)]
# Out:
#           budget                                    genres  \
# index
# 71     145000000                  Adventure Action Fantasy
# 83      27000000  Action Adventure Science Fiction Romance
# 323    100000000                      Comedy Drama Romance
# 381     90000000                     Fantasy Action Family
# 436     80000000                                    Comedy
# ...          ...                                       ...
# 4790           0                             Drama Foreign
# 4794           0                    Thriller Horror Comedy
# 4797           0                          Foreign Thriller
# 4799        9000                            Comedy Romance
# 4801           0                                       NaN
#
#                                            homepage      id keywords  \
# index
# 71                         http://www.themummy.com/    1735      NaN
# 83                                              NaN   79698      NaN
# ...

# %%
df = df[~( (df['genres'].isna()) | (df['keywords'].isna()) | (df['director'].isna()) | (df['cast'].isna()) )]
df
# Out:
#           budget                                    genres  \
# index
# 0      237000000  Action Adventure Fantasy Science Fiction
# 1      300000000                  Adventure Fantasy Action
# 2      245000000                    Action Adventure Crime
# 3      250000000               Action Crime Drama Thriller
# 4      260000000          Action Adventure Science Fiction
# ...          ...                                       ...
# 4795           0                                     Drama
# 4796        7000            Science Fiction Drama Thriller
# 4798      220000                     Action Crime Thriller
# 4800           0             Comedy Drama Romance TV Movie
# 4802           0                               Documentary
#
#                                                 homepage      id  \
# index
# 0                            http://www.avatarmovie.com/   19995
# 1           http://disney.go.com/disneypictures/pirates/     285
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4377 entries, 0 to 4802
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4377 non-null   int64
#  1   genres                4377 non-null   object
#  2   homepage              1616 non-null   object
#  3   id                    4377 non-null   int64
#  4   keywords              4377 non-null   object
#  5   original_language     4377 non-null   object
#  6   original_title        4377 non-null   object
#  7   overview              4375 non-null   object
#  8   popularity            4377 non-null   float64
#  9   production_companies  4377 non-null   object
#  10  production_countries  4377 non-null   object
#  11  release_date          4377 non-null   object
#  12  revenue               4377 non-null   int64
#  13  runtime               4375 non-null   float64
#  14  spoken_languages      4377 non-null   object
# ...

# %%
df[['title','genres','director','cast','keywords']]
# Out:
#                                           title  \
# index
# 0                                        Avatar
# 1      Pirates of the Caribbean: At World's End
# 2                                       Spectre
# 3                         The Dark Knight Rises
# 4                                   John Carter
# ...                                         ...
# 4795                                       Bang
# 4796                                     Primer
# 4798                                El Mariachi
# 4800                  Signed, Sealed, Delivered
# 4802                          My Date with Drew
#
#                                          genres           director  \
# index
# 0      Action Adventure Fantasy Science Fiction      James Cameron
# 1                      Adventure Fantasy Action     Gore Verbinski
# 2                        Action Adventure Crime         Sam Mendes
# 3                   Action Crime Drama Thriller  Christopher Nolan
# ...
